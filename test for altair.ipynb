# %%
import altair as alt
import pandas as pd

df = pd.read_csv("./DATA_CLEANED.csv", sep=",")

# %%
df.describe()
# Out:
#          Unnamed: 0     unnamed_0            qtr           down  \
# count  183460.00000  183460.00000  183460.000000  155933.000000
# mean    91729.50000   91729.50000       2.577864       2.003649
# std     52960.48453   52960.48453       1.129590       1.006810
# min         0.00000       0.00000       1.000000       1.000000
# 25%     45864.75000   45864.75000       2.000000       1.000000
# 50%     91729.50000   91729.50000       3.000000       2.000000
# 75%    137594.25000  137594.25000       4.000000       3.000000
# max    183459.00000  183459.00000       5.000000       4.000000
#
#           time_under  play_time_diff          yrdln        ydstogo  \
# count  183460.000000   183264.000000  183078.000000  183460.000000
# mean        7.376567       20.569081      28.471717       7.308928
# std         4.641226       18.290782      12.948864       4.874566
# min         0.000000        0.000000       1.000000       0.000000
# ...

# %%
alt.Chart(df[:100]).mark_point().encode(
    x = "down",
    y = "play_time_diff",
    color="ydsnet"
)
# Out:
# alt.Chart(...)
